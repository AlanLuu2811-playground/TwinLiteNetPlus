# %%
# !pwd
# Out:
# /home/alan_khang/dev/TwinLiteNetPlus

# %%
import numpy as np
import torch

# %%
b, c, h, w = 2, 3, 100, 100
x = torch.randn(b, c, h, w)
y = torch.randn(b, c, h, w)

# %%
z = torch.cat([x, y], dim=1)

# %%
z.shape
# Out:
# torch.Size([2, 6, 100, 100])

# %%
256*6
# Out:
# 1536

# %%
import torch.nn.functional as F

# %%
F.adaptive_avg_pool2d(z, (1, 1)).shape
# Out:
# torch.Size([2, 6, 1, 1])

# %%
z.shape
# Out:
# torch.Size([2, 6, 100, 100])
